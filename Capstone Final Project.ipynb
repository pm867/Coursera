# %% [markdown]
# # **A program For Photographers Event**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# XYZ is a company based in Toronto for organizing events. Currently, they are working on a project which will organize an event for seven days for a group of photographers from all over the world.
# The company has to determine a good program, including a hotel for the residence, a hall for meetings, places to visit, places of shopping, restaurants and cafes to eat and drink.
# The company has to make a list of places in Toronto, including the nearest restaurants, cafes and shopping stores for each place. And it has to provide a map in case the photographer don’t use digital applications for some reason.

# %% [markdown]
# ## **Data Description**

# %% [markdown]
# The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.

# %% [markdown]
# ## **Table of contents**

# %% [markdown]
# 1. Import Libraries
# 2. Define Foursquare Credentials
# 3. Search for Hotels
# 4. Define the city and get its latitude & longitude
# 5. Search for Hotels & clean dataframe
# 6. Search for Parks & clean dataframe
# 7. Search for Restaurants & clean dataframe
# 8. Search for Cafeteria & clean dataframe
# 9. Search for Shopping Stores & clean dataframe
# 10. Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together
# 11. Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %% [markdown]
# ## **Import Libraries**

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

# %% [markdown]
# ## **Define Foursquare Credentials**

# %%
ClIENT_ID = '4NYTHBL0ZJPS5MUV5DQZCWW5F0B502OEC0UT35XSVX4Y0NVE' # your Foursquare ID
ClIENT_SECRET = 'WDZ5JUDPK3KTE120B1JT1NV0VDNWT0FTKRFMWOJIEGF5S2V3' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: 4NYTHBL0ZJPS5MUV5DQZCWW5F0B502OEC0UT35XSVX4Y0NVE
# Foursquare_Secret:WDZ5JUDPK3KTE120B1JT1NV0VDNWT0FTKRFMWOJIEGF5S2V3

# %% [markdown]
# ## **Define the city and get its latitude & longitude**

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %% [markdown]
# ## **Search for Hotels**

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4NYTHBL0ZJPS5MUV5DQZCWW5F0B502OEC0UT35XSVX4Y0NVE&client_secret=WDZ5JUDPK3KTE120B1JT1NV0VDNWT0FTKRFMWOJIEGF5S2V3&ll=43.6534817,-79.3839347&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id        location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3   123 Queen Street West          CA       Toronto
# 1  51d212c3498ebf27dc469bc9  33 Gerrard Street West          CA       Toronto
# 2  4af96fbbf964a520c01122e3             1 King St W          CA       Toronto
# 3  51e48697498eded9073c6c17  33 Gerrard Street West          CA       Toronto
# 4  4ae61cf6f964a520caa421e3         200 Victoria St          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                324
# 1           Canada          at Yonge St                562
# 2           Canada         at Yonge St.                686
# 3           Canada                  NaN                522
# 4           Canada         at Shuter St                410
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [33 Gerrard Street West (at Yonge St), Toronto...
# 2  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 3       [33 Gerrard Street West, Toronto ON, Canada]
# 4  [200 Victoria St (at Shuter St), Toronto ON, C...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...     43.650594
# 1  [{'label': 'display', 'lat': 43.65849759157591...     43.658498
# 2  [{'label': 'display', 'lat': 43.6491395, 'lng'...     43.649139
# 3  [{'label': 'display', 'lat': 43.65809435580944...     43.658094
# 4  [{'label': 'display', 'lat': 43.65449797039222...     43.654498
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384530                   NaN             M5H 2M9             ON
# 1    -79.383097                   NaN             M5G 1Z4             ON
# 2    -79.377876                   NaN             M5H 1A1             ON
# 3    -79.382711                   NaN                 NaN             ON
# 4    -79.379035                   NaN                 NaN             ON
#
#                               name    referralId venuePage.id
# 0    Sheraton Centre Toronto Hotel  v-1586983213          NaN
# 1                    Chelsea Hotel  v-1586983213          NaN
# 2  One King West Hotel & Residence  v-1586983213          NaN
# 3    Crew Room Eaton Chelsea Hotel  v-1586983213          NaN
# 4             Pantages Hotel & Spa  v-1586983213          NaN

# %% [markdown]
# ## **Clean Hotel Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                               name categories                 address  cc  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West  CA
# 1                    Chelsea Hotel      Hotel  33 Gerrard Street West  CA
# 2  One King West Hotel & Residence      Hotel             1 King St W  CA
# 3    Crew Room Eaton Chelsea Hotel      Hotel  33 Gerrard Street West  CA
# 4             Pantages Hotel & Spa      Hotel         200 Victoria St  CA
#
#       city country   crossStreet  distance  \
# 0  Toronto  Canada   at York St.       324
# 1  Toronto  Canada   at Yonge St       562
# 2  Toronto  Canada  at Yonge St.       686
# 3  Toronto  Canada           NaN       522
# 4  Toronto  Canada  at Shuter St       410
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [33 Gerrard Street West (at Yonge St), Toronto...
# 2  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 3       [33 Gerrard Street West, Toronto ON, Canada]
# 4  [200 Victoria St (at Shuter St), Toronto ON, C...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...  43.650594 -79.384530
# 1  [{'label': 'display', 'lat': 43.65849759157591...  43.658498 -79.383097
# 2  [{'label': 'display', 'lat': 43.6491395, 'lng'...  43.649139 -79.377876
# 3  [{'label': 'display', 'lat': 43.65809435580944...  43.658094 -79.382711
# 4  [{'label': 'display', 'lat': 43.65449797039222...  43.654498 -79.379035
#
#   neighborhood postalCode state                        id
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1          NaN    M5G 1Z4    ON  51d212c3498ebf27dc469bc9
# 2          NaN    M5H 1A1    ON  4af96fbbf964a520c01122e3
# 3          NaN        NaN    ON  51e48697498eded9073c6c17
# 4          NaN        NaN    ON  4ae61cf6f964a520caa421e3

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2.head()
# Out:
#                               name categories                 address  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West
# 1                    Chelsea Hotel      Hotel  33 Gerrard Street West
# 2  One King West Hotel & Residence      Hotel             1 King St W
# 3    Crew Room Eaton Chelsea Hotel      Hotel  33 Gerrard Street West
# 4             Pantages Hotel & Spa      Hotel         200 Victoria St
#
#          lat        lng postalCode state
# 0  43.650594 -79.384530    M5H 2M9    ON
# 1  43.658498 -79.383097    M5G 1Z4    ON
# 2  43.649139 -79.377876    M5H 1A1    ON
# 3  43.658094 -79.382711        NaN    ON
# 4  43.654498 -79.379035        NaN    ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3.head()
# Out:
#                               name categories                 address  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West
# 1                    Chelsea Hotel      Hotel  33 Gerrard Street West
# 2  One King West Hotel & Residence      Hotel             1 King St W
# 5   The Rex Hotel Jazz & Blues Bar  Jazz Club          194 Queen St W
# 6                   VFM Test Hotel      Hotel          123 Test Drive
#
#          lat        lng postalCode state
# 0  43.650594 -79.384530    M5H 2M9    ON
# 1  43.658498 -79.383097    M5G 1Z4    ON
# 2  43.649139 -79.377876    M5H 1A1    ON
# 5  43.650505 -79.388577    M5V 1Z1    ON
# 6  43.658434 -79.387894    M2M 2M2    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name categories  \
# 0                  Sheraton Centre Toronto Hotel      Hotel
# 1                                  Chelsea Hotel      Hotel
# 2                One King West Hotel & Residence      Hotel
# 6                                 VFM Test Hotel      Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 9                                 St Regis Hotel      Hotel
# 22                    The Adelaide Hotel Toronto      Hotel
# 25                          DoubleTree by Hilton      Hotel
# 26  Marriott Downtown at CF Toronto Eaton Centre      Hotel
# 29                            Shangri-La Toronto      Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 2              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 6           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 9               325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 22              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 25     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 26          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 29     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name categories  \
# 0                  Sheraton Centre Toronto Hotel      Hotel
# 1                                  Chelsea Hotel      Hotel
# 2                One King West Hotel & Residence      Hotel
# 6                                 VFM Test Hotel      Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 9                                 St Regis Hotel      Hotel
# 22                    The Adelaide Hotel Toronto      Hotel
# 25                          DoubleTree by Hilton      Hotel
# 26  Marriott Downtown at CF Toronto Eaton Centre      Hotel
# 29                            Shangri-La Toronto      Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 2              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 6           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 9               325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 22              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 25     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 26          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 29     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                             name categories                address        lat  \
# 0  Sheraton Centre Toronto Hotel      Hotel  123 Queen Street West  43.650594
#
#         lng postalCode state
# 0 -79.38453    M5H 2M9    ON

# %% [markdown]
# ## **Search for Parks**

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4NYTHBL0ZJPS5MUV5DQZCWW5F0B502OEC0UT35XSVX4Y0NVE&client_secret=WDZ5JUDPK3KTE120B1JT1NV0VDNWT0FTKRFMWOJIEGF5S2V3&ll=43.6534817,-79.3839347&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 3  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
#
#                          id          location.address location.cc  \
# 0  4b170e47f964a5208cc123e3        691 University Ave          CA
# 1  4b54deadf964a520a3d027e3                       NaN          CA
# 2  59ddd7469ba3e51a75459568          382 Yonge Street          CA
# 3  4b9177e4f964a520d2be33e3                       NaN          CA
# 4  4bfc5019da7120a132df49fd  450 Adelaide Street West          CA
#
#   location.city location.country      location.crossStreet  location.distance  \
# 0       Toronto           Canada             at College St                887
# 1       Toronto           Canada                       NaN                663
# 2       Toronto           Canada                       NaN                652
# 3       Toronto           Canada                       NaN                389
# 4       Toronto           Canada  Brant St & Adelaide St W               1372
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2     [382 Yonge Street, Toronto ON M5G 1S8, Canada]
# 3                               [Toronto ON, Canada]
# 4  [450 Adelaide Street West (Brant St & Adelaide...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.6592634, 'lng'...     43.659263
# 3  [{'label': 'display', 'lat': 43.650735, 'lng':...     43.650735
# 4  [{'label': 'display', 'lat': 43.64738759338116...     43.647388
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.382632             M5G 1S8             ON
# 3    -79.386921                 NaN             ON
# 4    -79.398752                 NaN             ON
#
#                                  name    referralId venuePage.id
# 0         Queen's Park Subway Station  v-1586983354          NaN
# 1                         Grange Park  v-1586983354          NaN
# 2       Crunch Fitness - College Park  v-1586983354    532736199
# 3  TTC Streetcar #403 - Victoria park  v-1586983354          NaN
# 4   St. Andrews Playground / Dog Park  v-1586983354          NaN

# %% [markdown]
# ## **Clean Park Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                  name            categories  \
# 0         Queen's Park Subway Station         Metro Station
# 1                         Grange Park                  Park
# 2       Crunch Fitness - College Park  Gym / Fitness Center
# 3  TTC Streetcar #403 - Victoria park    Light Rail Station
# 4   St. Andrews Playground / Dog Park                  Park
#
#                     address  cc     city country               crossStreet  \
# 0        691 University Ave  CA  Toronto  Canada             at College St
# 1                       NaN  CA  Toronto  Canada                       NaN
# 2          382 Yonge Street  CA  Toronto  Canada                       NaN
# 3                       NaN  CA  Toronto  Canada                       NaN
# 4  450 Adelaide Street West  CA  Toronto  Canada  Brant St & Adelaide St W
#
#    distance                                   formattedAddress  \
# 0       887  [691 University Ave (at College St), Toronto O...
# 1       663  [btwn College, University, Queen & Spadina, To...
# 2       652     [382 Yonge Street, Toronto ON M5G 1S8, Canada]
# 3       389                               [Toronto ON, Canada]
# 4      1372  [450 Adelaide Street West (Brant St & Adelaide...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.6592634, 'lng'...  43.659263 -79.382632
# 3  [{'label': 'display', 'lat': 43.650735, 'lng':...  43.650735 -79.386921
# 4  [{'label': 'display', 'lat': 43.64738759338116...  43.647388 -79.398752
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2    M5G 1S8    ON  59ddd7469ba3e51a75459568
# 3        NaN    ON  4b9177e4f964a520d2be33e3
# 4        NaN    ON  4bfc5019da7120a132df49fd

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                        name  \
# 0               Queen's Park Subway Station
# 1                               Grange Park
# 2             Crunch Fitness - College Park
# 3        TTC Streetcar #403 - Victoria park
# 4         St. Andrews Playground / Dog Park
# 5                               Berczy Park
# 6                              Queen's Park
# 7          Residences at College Park North
# 8                             One Park Lane
# 9                    Physiomed College Park
# 10                     Clarence Square Park
# 11         Toothworks - College Park Dental
# 12                  Moss Park Tennis Courts
# 13                  St Lawrence on the Park
# 14                      Riverdale Park West
# 15                              Regent Park
# 16             Regent Park Community Centre
# 17                     Bellevue Square Park
# 18                                 HTO Park
# 19                      Tommy Thompson Park
# 20                   Trinity Bellwoods Park
# 21  GoodLife Fitness Toronto Bloor and Park
# 22                      Riverdale Park East
# 23                      RBC WaterPark Place
# 24                        Barbara Hall Park
# 25                                High Park
# 26                       Canoe Landing Park
# 27                             Wilfrid Park
# 28                  Park Hyatt Bridal Suite
# 29      Regent Park Community Health Centre
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                       Gym / Fitness Center              382 Yonge Street
# 3                         Light Rail Station                           NaN
# 4                                       Park      450 Adelaide Street West
# 5                                       Park        35 Wellington St. East
# 6                                       Park               University Ave.
# 7   Residential Building (Apartment / Condo)                   763 Bay St.
# 8   Residential Building (Apartment / Condo)                 280 Simcoe St
# 9                             Medical Center                  382 Yonge St
# 10                                      Park                   Spadina Ave
# 11                          Dentist's Office        444 Yonge St, Unit M16
# 12                              Tennis Court                     Moss Park
# 13                                  Building               65 Scadding Ave
# 14                                      Park               500 Gerrard St.
# 15                              Neighborhood                           NaN
# 16                          Community Center               465 Dundas St E
# 17                                      Park  btwn Bellevue & Augusta Ave.
# 18                                      Park                  Queen's Quay
# 19                                      Park                     Leslie St
# 20                                      Park            1053 Dundas St. W.
# 21                                       Gym                     8 Park Rd
# 22                                      Park             550 Broadview Ave
# 23                                    Office                88 Queens Quay
# 24                                      Park                 519 Church St
# 25                                      Park              1873 Bloor St. W
# 26                                      Park             50 Fort York Blvd
# 27                                    Office                           NaN
# 28                                     Hotel                   4 Avenue Rd
# 29                          Community Center               465 Dundas St E
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.659263 -79.382632    M5G 1S8    ON
# 3   43.650735 -79.386921        NaN    ON
# 4   43.647388 -79.398752        NaN    ON
# 5   43.648048 -79.375172        NaN    ON
# 6   43.663946 -79.392180    M5R 2E8    ON
# 7   43.659822 -79.385159    M5G 2R3    ON
# 8   43.655442 -79.390056    M5T 2Y5    ON
# 9   43.659240 -79.382860    M5B 1S8    ON
# 10  43.644222 -79.394230        NaN    ON
# 11  43.660009 -79.383905        NaN    ON
# 12  43.655337 -79.371923        NaN    ON
# 13  43.648963 -79.364868        NaN    ON
# 14  43.666048 -79.360941    M5A 2H3    ON
# 15  43.660009 -79.364191        NaN    ON
# 16  43.659512 -79.363048    M5A 2B2    ON
# 17  43.653610 -79.402199    M5T 2N4    ON
# 18  43.637949 -79.387820        NaN    ON
# 19  43.634180 -79.323671        NaN    ON
# 20  43.647072 -79.413756    M5H 2N2    ON
# 21  43.671302 -79.384691    M4W 3G8    ON
# 22  43.669951 -79.355493    M4K 2P1    ON
# 23  43.641075 -79.379154        NaN    ON
# 24  43.666879 -79.381068    M4Y 2K9    ON
# 25  43.646479 -79.463425    M6R 2Z3    ON
# 26  43.638762 -79.397067    M5V 3Z1    ON
# 27  43.650999 -79.364915        NaN   NaN
# 28  43.668849 -79.394460        NaN    ON
# 29  43.659572 -79.365759        NaN    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                        name  \
# 0               Queen's Park Subway Station
# 2             Crunch Fitness - College Park
# 6                              Queen's Park
# 7          Residences at College Park North
# 8                             One Park Lane
# 9                    Physiomed College Park
# 14                      Riverdale Park West
# 16             Regent Park Community Centre
# 17                     Bellevue Square Park
# 20                   Trinity Bellwoods Park
# 21  GoodLife Fitness Toronto Bloor and Park
# 22                      Riverdale Park East
# 24                        Barbara Hall Park
# 25                                High Park
# 26                       Canoe Landing Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 2                       Gym / Fitness Center              382 Yonge Street
# 6                                       Park               University Ave.
# 7   Residential Building (Apartment / Condo)                   763 Bay St.
# 8   Residential Building (Apartment / Condo)                 280 Simcoe St
# 9                             Medical Center                  382 Yonge St
# 14                                      Park               500 Gerrard St.
# 16                          Community Center               465 Dundas St E
# 17                                      Park  btwn Bellevue & Augusta Ave.
# 20                                      Park            1053 Dundas St. W.
# 21                                       Gym                     8 Park Rd
# 22                                      Park             550 Broadview Ave
# 24                                      Park                 519 Church St
# 25                                      Park              1873 Bloor St. W
# 26                                      Park             50 Fort York Blvd
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 2   43.659263 -79.382632    M5G 1S8    ON
# 6   43.663946 -79.392180    M5R 2E8    ON
# 7   43.659822 -79.385159    M5G 2R3    ON
# 8   43.655442 -79.390056    M5T 2Y5    ON
# 9   43.659240 -79.382860    M5B 1S8    ON
# 14  43.666048 -79.360941    M5A 2H3    ON
# 16  43.659512 -79.363048    M5A 2B2    ON
# 17  43.653610 -79.402199    M5T 2N4    ON
# 20  43.647072 -79.413756    M5H 2N2    ON
# 21  43.671302 -79.384691    M4W 3G8    ON
# 22  43.669951 -79.355493    M4K 2P1    ON
# 24  43.666879 -79.381068    M4Y 2K9    ON
# 25  43.646479 -79.463425    M6R 2Z3    ON
# 26  43.638762 -79.397067    M5V 3Z1    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 6             Queen's Park       Park               University Ave.
# 14     Riverdale Park West       Park               500 Gerrard St.
# 17    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 20  Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 22     Riverdale Park East       Park             550 Broadview Ave
# 24       Barbara Hall Park       Park                 519 Church St
# 25               High Park       Park              1873 Bloor St. W
# 26      Canoe Landing Park       Park             50 Fort York Blvd
#
#           lat        lng postalCode state
# 6   43.663946 -79.392180    M5R 2E8    ON
# 14  43.666048 -79.360941    M5A 2H3    ON
# 17  43.653610 -79.402199    M5T 2N4    ON
# 20  43.647072 -79.413756    M5H 2N2    ON
# 22  43.669951 -79.355493    M4K 2P1    ON
# 24  43.666879 -79.381068    M4Y 2K9    ON
# 25  43.646479 -79.463425    M6R 2Z3    ON
# 26  43.638762 -79.397067    M5V 3Z1    ON

# %% [markdown]
# ## **Search for Restaurants**

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4NYTHBL0ZJPS5MUV5DQZCWW5F0B502OEC0UT35XSVX4Y0NVE&client_secret=WDZ5JUDPK3KTE120B1JT1NV0VDNWT0FTKRFMWOJIEGF5S2V3&ll=43.6534817,-79.3839347&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 2  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4ad4c05cf964a52006f620e3  37 King Street East          CA       Toronto
# 2  4ada5d5bf964a520e92121e3         35 Church St          CA       Toronto
# 3  4ae29812f964a520288f21e3     309 Spadina Ave.          CA       Toronto
# 4  4b266f05f964a520657b24e3      266 Spadina Ave          CA       Toronto
#
#   location.country              location.crossStreet  location.distance  \
# 0           Canada                               NaN                224
# 1           Canada  at Le Meridien King Edward Hotel                763
# 2           Canada                     at Front St E                973
# 3           Canada    btwn Dundas St. W & D'Arcy St.               1160
# 4           Canada                    at Willison Sq               1143
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [37 King Street East (at Le Meridien King Edwa...
# 2  [35 Church St (at Front St E), Toronto ON M5E ...
# 3  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 4  [266 Spadina Ave (at Willison Sq), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.64929834396347...     43.649298
# 2  [{'label': 'display', 'lat': 43.64882370529773...     43.648824
# 3  [{'label': 'display', 'lat': 43.65386562507761...     43.653866
# 4  [{'label': 'display', 'lat': 43.6522783893466,...     43.652278
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.385931                   NaN             M5G 1R3             ON
# 1    -79.376431                   NaN             M5C 1E9             ON
# 2    -79.373702                   NaN             M5E 1T3             ON
# 3    -79.398334                   NaN             M5T 2E6             ON
# 4    -79.398039                   NaN             M5T 2E4             ON
#
#                               name    referralId venuePage.id
# 0  Hemispheres Restaurant & Bistro  v-1586983381          NaN
# 1            Victoria's Restaurant  v-1586983381    498556908
# 2   The Hot House Restaurant & Bar  v-1586983381          NaN
# 3          Swatow Restaurant 汕頭小食家  v-1586983381          NaN
# 4   Goldstone Noodle Restaurant 金石  v-1586983381          NaN

# %% [markdown]
# ## **Clean Restaurant Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name           categories              address  \
# 0  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 1            Victoria's Restaurant           Restaurant  37 King Street East
# 2   The Hot House Restaurant & Bar  American Restaurant         35 Church St
# 3          Swatow Restaurant 汕頭小食家   Chinese Restaurant     309 Spadina Ave.
# 4   Goldstone Noodle Restaurant 金石         Noodle House      266 Spadina Ave
#
#    cc     city country                       crossStreet  distance  \
# 0  CA  Toronto  Canada                               NaN       224
# 1  CA  Toronto  Canada  at Le Meridien King Edward Hotel       763
# 2  CA  Toronto  Canada                     at Front St E       973
# 3  CA  Toronto  Canada    btwn Dundas St. W & D'Arcy St.      1160
# 4  CA  Toronto  Canada                    at Willison Sq      1143
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [37 King Street East (at Le Meridien King Edwa...
# 2  [35 Church St (at Front St E), Toronto ON M5E ...
# 3  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 4  [266 Spadina Ave (at Willison Sq), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1  [{'label': 'display', 'lat': 43.64929834396347...  43.649298 -79.376431
# 2  [{'label': 'display', 'lat': 43.64882370529773...  43.648824 -79.373702
# 3  [{'label': 'display', 'lat': 43.65386562507761...  43.653866 -79.398334
# 4  [{'label': 'display', 'lat': 43.6522783893466,...  43.652278 -79.398039
#
#   neighborhood postalCode state                        id
# 0          NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1          NaN    M5C 1E9    ON  4ad4c05cf964a52006f620e3
# 2          NaN    M5E 1T3    ON  4ada5d5bf964a520e92121e3
# 3          NaN    M5T 2E6    ON  4ae29812f964a520288f21e3
# 4          NaN    M5T 2E4    ON  4b266f05f964a520657b24e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                            Victoria's Restaurant               Restaurant
# 2                   The Hot House Restaurant & Bar      American Restaurant
# 3                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 4                   Goldstone Noodle Restaurant 金石             Noodle House
# 5                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 6               Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 7                                   360 Restaurant                 Wine Bar
# 8                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 9                           Azure Restaurant & Bar               Restaurant
# 10                    Aroma Fine Indian Restaurant        Indian Restaurant
# 11                               Studio Restaurant           Breakfast Spot
# 12              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 13                   Green Tea Restaurant Downtown       Chinese Restaurant
# 14                         Victor Restaurant & Bar                      Bar
# 15                     Cottage Restaurant & Lounge          Thai Restaurant
# 16              Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 17         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 18               Kensington Cornerstone Restaurant           Breakfast Spot
# 19                        Ka Chi Korean Restaurant        Korean Restaurant
# 20                           Sightlines Restaurant      American Restaurant
# 21  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 22                               Arriba Restaurant               Restaurant
# 23                 Kyoto House Japanese Restaurant         Sushi Restaurant
# 24                           Restaurant | Adelaide               Restaurant
# 25             Richtree Natural Market Restaurants               Restaurant
# 26                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 27                   Micheal's Restaurant and Deli                      Bar
# 28                      Hendricks Restaurant & Bar               Restaurant
# 29                         Osgoode Hall Restaurant  New American Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 2                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 3                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 4                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 5                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 6                988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 7                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 8                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 9                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 10                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 11                   389 Church St.  43.661500 -79.379319        M5B    ON
# 12                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 13  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 14                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 15                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 16                 280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 17                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 18               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 19                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 20                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 21            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 22                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 23              143 Dundas St. West  43.655381 -79.385270        NaN    ON
# 24          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 25                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 26                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 27                   566 Queen St W  43.647289 -79.403493        NaN    ON
# 28                  Yonge And Queen  43.653415 -79.379698    M5G 2H6    ON
# 29                   130 Queen St W  43.651979 -79.385049    M5H 2N6   NaN

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name            categories  \
# 0                  Hemispheres Restaurant & Bistro   American Restaurant
# 1                            Victoria's Restaurant            Restaurant
# 2                   The Hot House Restaurant & Bar   American Restaurant
# 3                          Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 4                   Goldstone Noodle Restaurant 金石          Noodle House
# 5                         New Sky Restaurant 小沙田食家    Chinese Restaurant
# 7                                   360 Restaurant              Wine Bar
# 8                           Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 9                           Azure Restaurant & Bar            Restaurant
# 10                    Aroma Fine Indian Restaurant     Indian Restaurant
# 11                               Studio Restaurant        Breakfast Spot
# 13                   Green Tea Restaurant Downtown    Chinese Restaurant
# 14                         Victor Restaurant & Bar                   Bar
# 15                     Cottage Restaurant & Lounge       Thai Restaurant
# 17         Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 18               Kensington Cornerstone Restaurant        Breakfast Spot
# 19                        Ka Chi Korean Restaurant     Korean Restaurant
# 21  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 22                               Arriba Restaurant            Restaurant
# 24                           Restaurant | Adelaide            Restaurant
# 25             Richtree Natural Market Restaurants            Restaurant
# 26                   Hong Shing Chinese Restaurant    Chinese Restaurant
# 28                      Hendricks Restaurant & Bar            Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 2                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 3                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 4                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 5                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 7                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 8                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 9                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 10                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 11                   389 Church St.  43.661500 -79.379319        M5B    ON
# 13  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 14                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 15                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 17                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 18               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 19                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 21            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 22                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 24          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 25                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 26                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 28                  Yonge And Queen  43.653415 -79.379698    M5G 2H6    ON

# %% [markdown]
# ## **Search for Cafeteria**

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4NYTHBL0ZJPS5MUV5DQZCWW5F0B502OEC0UT35XSVX4Y0NVE&client_secret=WDZ5JUDPK3KTE120B1JT1NV0VDNWT0FTKRFMWOJIEGF5S2V3&ll=43.6534817,-79.3839347&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  4b57256bf964a520332828e3                                      Yonge
# 3  53bd6dfe498e6c1d3bc9333e                                        NaN
# 4  524f1c8f498e983dde61ada0                         89 Chestnut Street
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada               Dundas
# 3          CA       Toronto           Canada                  NaN
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                448  [The Hospital for Sick Children (SickKids), To...
# 1               1246  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                387               [Yonge (Dundas), Toronto ON, Canada]
# 3                505                               [Toronto ON, Canada]
# 4                584           [89 Chestnut Street, Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.65603785909391...     43.656038
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...     43.648231
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.380672                 NaN             ON
# 3    -79.389443                 NaN             ON
# 4    -79.384045                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1586983408
# 1              Stay Cafeteria 慢走  v-1586983408
# 2                Sears Cafeteria  v-1586983408
# 3  Industrial Alliance Cafeteria  v-1586983408
# 4        Chestnut Tree Cafeteria  v-1586983408

# %% [markdown]
# ## **Clean Cafeteria Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                Sears Cafeteria            Food Court
# 3  Industrial Alliance Cafeteria             Cafeteria
# 4        Chestnut Tree Cafeteria             Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                                      Yonge  CA  Toronto  Canada
# 3                                        NaN  CA  Toronto  Canada
# 4                         89 Chestnut Street  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       448  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St      1246  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2        Dundas       387               [Yonge (Dundas), Toronto ON, Canada]
# 3           NaN       505                               [Toronto ON, Canada]
# 4           NaN       584           [89 Chestnut Street, Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.65603785909391...  43.656038 -79.380672
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...  43.648231 -79.384045
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  4b57256bf964a520332828e3
# 3        NaN    ON  53bd6dfe498e6c1d3bc9333e
# 4        NaN    ON  524f1c8f498e983dde61ada0

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                         Sears Cafeteria            Food Court
# 3           Industrial Alliance Cafeteria             Cafeteria
# 4                 Chestnut Tree Cafeteria             Cafeteria
# 5                          OCAD Cafeteria     College Cafeteria
# 6                   Ryerson Hub Cafeteria     College Cafeteria
# 7                         Dears Cafeteria          Dessert Shop
# 8                      SickKids Cafeteria            Food Court
# 9           De La Salle College Cafeteria     College Cafeteria
# 10                      Med Sci Cafeteria     College Cafeteria
# 11              Macdonald Block Cafeteria             Cafeteria
# 12                      Robarts Cafeteria     College Cafeteria
# 13                          OMP Cafeteria             Cafeteria
# 14                       Rogers Cafeteria            Food Court
# 15                      Choices Cafeteria            Food Court
# 16  George Brown College St. James Campus     Community College
# 17                             Marketeria            Restaurant
# 18                                The Hub     College Cafeteria
# 19    Cafeteria, Lawrence Park Collegiate           High School
# 20    Cafeteria, Lawrence Park Collegiate           Event Space
# 21                       Kasala Cafeteria    African Restaurant
# 22                           CC Cafeteria     College Cafeteria
# 23               Estonian House Cafeteria                  Café
# 24                          Innis College        Student Center
# 25                             Radio Cafe            Food Court
# 26                      Glendon Cafeteria     College Cafeteria
# 27     Lawrence Park Collegiate Cafeteria           High School
# 28                           L5 Cafeteria      Cuban Restaurant
# 29  6th Floor Cafeteria 12 Concorde Place                  Café
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                                       Yonge  43.656038 -79.380672
# 3                                         NaN  43.655657 -79.389443
# 4                          89 Chestnut Street  43.648231 -79.384045
# 5                              100 McCaul St.  43.652780 -79.391762
# 6                            350 Victoria St.  43.658475 -79.377653
# 7                                         NaN  43.654179 -79.392555
# 8                       555 University Avenue  43.657584 -79.375652
# 9                          131 Farnham Avenue  43.683003 -79.397815
# 10                                        NaN  43.660260 -79.392977
# 11                                        NaN  43.663212 -79.388062
# 12                         130 St. George St.  43.664864 -79.399766
# 13                           1 Mount Pleasant  43.669801 -79.379790
# 14                                        NaN  43.669904 -79.379748
# 15                         200 Bloor Street E  43.671411 -79.381849
# 16                          200 King St. East  43.651366 -79.370158
# 17                                30 Bond St.  43.653585 -79.378843
# 18                           350 Victoria St.  43.658585 -79.380622
# 19                                        NaN  43.721732 -79.409600
# 20                                        NaN  43.723286 -79.412222
# 21                                      Bloor  43.660759 -79.424018
# 22                             951 Carlaw Ave  43.684631 -79.348862
# 23                       958 Broadview avenue  43.681763 -79.358246
# 24                               2 Sussex Ave  43.665556 -79.399298
# 25                          333 Bloor st east  43.671696 -79.380617
# 26                           2275 Bayview Ave  43.727383 -79.378080
# 27                                        NaN  43.722757 -79.413734
# 28                                        NaN  43.723019 -79.345012
# 29                          12 Concorde Place  43.721861 -79.329339
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3         NaN    ON
# 4         NaN    ON
# 5         NaN    ON
# 6         NaN    ON
# 7         NaN   NaN
# 8         NaN    ON
# 9     M4V 1H7    ON
# 10        NaN    ON
# 11        NaN   NaN
# 12        NaN    ON
# 13        NaN    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN    ON
# 17    M5B 1W8    ON
# 18    M5B 2K3    ON
# 19        NaN   NaN
# 20        NaN   NaN
# 21        NaN   NaN
# 22        NaN    ON
# 23        NaN    ON
# 24    M5S 1J5    ON
# 25        NaN    ON
# 26        NaN    ON
# 27        NaN    ON
# 28        NaN   NaN
# 29    m3c 3k7    ON

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 9           De La Salle College Cafeteria  College Cafeteria
# 17                             Marketeria         Restaurant
# 18                                The Hub  College Cafeteria
# 24                          Innis College     Student Center
# 29  6th Floor Cafeteria 12 Concorde Place               Café
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 9   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 17         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 18    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 24        2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 29   12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %% [markdown]
# ## **Search for Shopping Stores**

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4NYTHBL0ZJPS5MUV5DQZCWW5F0B502OEC0UT35XSVX4Y0NVE&client_secret=WDZ5JUDPK3KTE120B1JT1NV0VDNWT0FTKRFMWOJIEGF5S2V3&ll=43.6534817,-79.3839347&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
#
#                          id    location.address location.cc location.city  \
# 0  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 1  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 2  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada    btw York & Bay St                741
# 1           Canada    Queen Street West                424
# 2           Canada  btwn Queen & Dundas                287
#
#                            location.formattedAddress  \
# 0  [66 Wellington St W (btw York & Bay St), Toron...
# 1  [176 Yonge Street (Queen Street West), Toronto...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 1  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 2                                                NaN     43.654540
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.380932                            NaN             M5K 1A1
# 1    -79.379192                            NaN             M5C 2L7
# 2    -79.380677  Downtown Toronto, Toronto, ON             M5B 2H1
#
#   location.state                                        name    referralId
# 0             ON                TD Centre Shopping Concourse  v-1586983426
# 1             ON  Saks Fifth Avenue Club - Personal Shopping  v-1586983426
# 2             ON                     CF Toronto Eaton Centre  v-1586983426

# %% [markdown]
# ## **Clean Shopping Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                TD Centre Shopping Concourse     Shopping Mall
# 1  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 2                     CF Toronto Eaton Centre     Shopping Mall
#
#               address  cc     city country          crossStreet  distance  \
# 0  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       741
# 1    176 Yonge Street  CA  Toronto  Canada    Queen Street West       424
# 2        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       287
#
#                                     formattedAddress  \
# 0  [66 Wellington St W (btw York & Bay St), Toron...
# 1  [176 Yonge Street (Queen Street West), Toronto...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 1  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 2                                                NaN  43.654540 -79.380677
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 1                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 2  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                TD Centre Shopping Concourse     Shopping Mall
# 1  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 2                     CF Toronto Eaton Centre     Shopping Mall
#
#               address        lat        lng postalCode state
# 0  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 1    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 2        220 Yonge St  43.654540 -79.380677    M5B 2H1    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
# 2       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654540
#
#          lng postalCode state
# 0 -79.380932    M5K 1A1    ON
# 2 -79.380677    M5B 2H1    ON

# %% [markdown]
# ## **Generate maps to visualize venues and how they cluster together**

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                     name         categories  \
# 0          Sheraton Centre Toronto Hotel              Hotel
# 1                      Stay Cafeteria 慢走   Asian Restaurant
# 2          De La Salle College Cafeteria  College Cafeteria
# 3                             Marketeria         Restaurant
# 4                                The Hub  College Cafeteria
# 5                          Innis College     Student Center
# 6  6th Floor Cafeteria 12 Concorde Place               Café
# 7           TD Centre Shopping Concourse      Shopping Mall
# 8                CF Toronto Eaton Centre      Shopping Mall
#
#                  address        lat        lng postalCode state
# 0  123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1        388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 2     131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 3            30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 4       350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 5           2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 6      12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 7     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 8           220 Yonge St  43.654540 -79.380677    M5B 2H1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name            categories  \
# 0                                     Queen's Park                  Park
# 1                              Riverdale Park West                  Park
# 2                             Bellevue Square Park                  Park
# 3                           Trinity Bellwoods Park                  Park
# 4                              Riverdale Park East                  Park
# 5                                Barbara Hall Park                  Park
# 6                                        High Park                  Park
# 7                               Canoe Landing Park                  Park
# 8                  Hemispheres Restaurant & Bistro   American Restaurant
# 9                            Victoria's Restaurant            Restaurant
# 10                  The Hot House Restaurant & Bar   American Restaurant
# 11                         Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 12                  Goldstone Noodle Restaurant 金石          Noodle House
# 13                        New Sky Restaurant 小沙田食家    Chinese Restaurant
# 14                                  360 Restaurant              Wine Bar
# 15                          Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 16                          Azure Restaurant & Bar            Restaurant
# 17                    Aroma Fine Indian Restaurant     Indian Restaurant
# 18                               Studio Restaurant        Breakfast Spot
# 19                   Green Tea Restaurant Downtown    Chinese Restaurant
# 20                         Victor Restaurant & Bar                   Bar
# 21                     Cottage Restaurant & Lounge       Thai Restaurant
# 22         Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 23               Kensington Cornerstone Restaurant        Breakfast Spot
# 24                        Ka Chi Korean Restaurant     Korean Restaurant
# 25  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 26                               Arriba Restaurant            Restaurant
# 27                           Restaurant | Adelaide            Restaurant
# 28             Richtree Natural Market Restaurants            Restaurant
# 29                   Hong Shing Chinese Restaurant    Chinese Restaurant
# 30                      Hendricks Restaurant & Bar            Restaurant
# 31                               Stay Cafeteria 慢走      Asian Restaurant
# 32                   De La Salle College Cafeteria     College Cafeteria
# 33                                      Marketeria            Restaurant
# 34                                         The Hub     College Cafeteria
# 35                                   Innis College        Student Center
# 36           6th Floor Cafeteria 12 Concorde Place                  Café
#
#                             address        lat        lng postalCode state
# 0                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 2      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 3                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 4                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 5                     519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 6                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 7                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 8               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 9               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 10                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 11                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 12                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 13                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 14                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 15                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 16                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 17                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 18                   389 Church St.  43.661500 -79.379319        M5B    ON
# 19  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 20                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 21                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 22                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 23               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 24                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 25            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 26                  1 Blue Jays Way  43.641479 -79.389074    M5V 1J4    ON
# 27          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 28                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 29                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 30                  Yonge And Queen  43.653415 -79.379698    M5G 2H6    ON
# 31                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 32               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 33                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 34                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 35                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 36                12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
